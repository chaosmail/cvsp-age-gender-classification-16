# %%
# %matplotlib inline
import PIL
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import os.path as fs

# %%
DATA_DIR = '../data/imdb-wiki-tiny-dataset'

TRAIN_DATA_OBJ = 'train_data'
VAL_DATA_OBJ = 'val_data'
TEST_DATA_OBJ = 'test_data'

img_per_row = 10
rows = 10

# %%
im = Image.open('../data/wiki_crop/00/37500_1944-01-23_2010.jpg')
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=228x228 at 0x7F1B51EB4198>

# %%
data = np.asarray(im)
data.shape
# Out:
# (228, 228, 3)

# %%
data[0,0,:]
# Out:
# array([213, 231, 231], dtype=uint8)

# %%
data_rs = data.reshape((3,228,228))
print(data_rs.shape)
print(data_rs[:,0,0])
# Out:
# (3, 228, 228)
# [213 143 141]

# %%
data_tp =  data.transpose((2,1,0))
print(data_tp.shape)
print(data_tp[:,0,0])
# Out:
# (3, 228, 228)
# [213 231 231]

# %%
data_ra = np.rollaxis(np.rollaxis(data, 2, 0), 2, 1)
print(data_ra.shape)
print(data_ra[:,0,0])
# Out:
# (3, 228, 228)
# [213 231 231]

# %%
data_rtp = data_tp.transpose((2,1,0))
print(data_rtp.shape)
print(data_rtp[0,0,:])
# Out:
# (228, 228, 3)
# [213 231 231]

# %% [markdown]
# # Check Transformation

# %%
# Out:
# '/home/ckoerner/software/cvsp-age-gender-classification-16/analyse'

# %%
from dataset import TinyImdbWikiAgeDataset as Dataset
import utils

DATASET_DIR = 'data/imdb-wiki-tiny-dataset'
ds_train = Dataset(DATASET_DIR, 'train')

tform = get_normalization_transform(
  means=ds_train.get_mean(per_channel=True),
  stds=ds_train.get_stddev(per_channel=True)
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-46-64ed1515f87e> in <module>()
#       2 sys.path.append("/home/ckoerner/software/cvsp-age-gender-classification-16/cnn_keras/dataset")
#       3
# ----> 4 from dataset import TinyImdbWikiAgeDataset as Dataset
#       5 import utils
#       6
#
# ImportError: No module named 'dataset'
