# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
sys.path.append(os.path.join(module_path, 'cnn-keras-update'))

# %%
DATA_DIR = '../data/imdb-wiki-tiny-dataset'

TRAIN_DATA_OBJ = 'train_data'

X_train = np.load(fs.join(DATA_DIR, TRAIN_DATA_OBJ + '_00.npy')).astype(np.float32)

# %%
from keras.preprocessingrocessing import image
# Out:
# Using Theano backend.
# Using gpu device 0: Quadro K620M (CNMeM is disabled, cuDNN 5004)
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-17c2fe118b2e> in <module>()
# ----> 1 from keras.preprocessingrocessing import image
#
# ImportError: No module named 'keras.preprocessingrocessing'

# %%
def flip(X):
    return X.transpose((2,1,0))

# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
for i in range(3):
    img = image.flip_axis(X_train[0], 1)
    plt.figure()
    plt.imshow(flip(img))

# %%
for i in range(5):
    img = image.random_shift(X_train[0], 0.1, 0.1)
    plt.figure()
    plt.imshow(flip(img))

# %%
for i in range(5):
    img = image.random_zoom(X_train[0], [0.9,1.2])
    plt.figure()
    plt.imshow(flip(img))

# %%
for i in range(5):
    img = image.random_shear(X_train[0], 0.1)
    plt.figure()
    plt.imshow(flip(img))

# %%
for i in [0, 20, 40]:
    img = image.random_rotation(X_train[0], i)
    plt.figure()
    plt.imshow(flip(img))
